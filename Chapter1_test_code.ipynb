# %% [markdown]
# <a href="https://colab.research.google.com/github/sidharth-157/Colab/blob/main/Chapter1_test_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
! pip install tensorflow==2.1.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.1.0 (from versions: 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.13.0rc0, 2.13.0rc1)
# ERROR: No matching distribution found for tensorflow==2.1.0

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
print(tf.__version__)
# Out:
# 2.12.0

# %%
#x_points = np.random.randint(low=3,high=100,size=10,dtype=float)

#x_points = np.array([53,43,15,87,44,28,93],dtype=float)

x = np.array([-1.0,0.0,1.0,2.0,3.0,4.0],dtype=float)

y = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0],dtype=float)

# %%
#type(x_points)
x_points
# Out:
# array([53., 43., 15., 87., 44., 28., 93.])

# %%
def equation(x):
  y= 2*x - 1
  return y

# %%
y_points = 2 * x_points - 1

# %%
y_points
# Out:
# array([105.,  85.,  29., 173.,  87.,  55., 185.])

# %%
print(equation(30))
# Out:
# 59

# %%
print(model.predict([30]))
# Out:
# 1/1 [==============================] - 0s 53ms/step
# [[58.914062]]

# %%
layer0 = Dense(units=1,input_shape=[1])
model = Sequential([layer0])
model.compile(optimizer='sgd', loss=tf.keras.losses.MeanSquaredError())
model.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 203ms/step - loss: 37.8175
# Epoch 2/500
# 1/1 [==============================] - 0s 6ms/step - loss: 30.0990
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 24.0193
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 19.2292
# Epoch 5/500
# 1/1 [==============================] - 0s 7ms/step - loss: 15.4538
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 12.4767
# Epoch 7/500
# 1/1 [==============================] - 0s 6ms/step - loss: 10.1280
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.2738
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8086
# Epoch 10/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.6498
# Epoch 11/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.7321
# Epoch 12/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.0041
# ...

# %%
model.compile(optimizer='SGD',loss='mean_squared_error')
#model.compile(optimizer=tf.keras.optimizers.SGD,loss=tf.keras.losses.MeanSquaredError)
#model.compile(optimizer='sgd', loss=tf.keras.losses.MeanSquaredError())
model.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 199ms/step - loss: 46.4857
# Epoch 2/500
# 1/1 [==============================] - 0s 6ms/step - loss: 36.6543
# Epoch 3/500
# 1/1 [==============================] - 0s 6ms/step - loss: 28.9178
# Epoch 4/500
# 1/1 [==============================] - 0s 6ms/step - loss: 22.8294
# Epoch 5/500
# 1/1 [==============================] - 0s 5ms/step - loss: 18.0378
# Epoch 6/500
# 1/1 [==============================] - 0s 7ms/step - loss: 14.2663
# Epoch 7/500
# 1/1 [==============================] - 0s 5ms/step - loss: 11.2976
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.9605
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 7.1203
# Epoch 10/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.6710
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.5294
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.6298
# ...

# %%
print(layer0.get_weights())
# Out:
# [array([[-0.01733322]], dtype=float32), array([-0.02686433], dtype=float32)]

# %%
seq = tf.keras.Sequential
dense = tf.keras.layers.Dense
layer0 = dense(units=1,input_shape=[1])
model = seq([layer0])
model.compile(optimizer='adam', loss='mean_squared_logarithmic_error')
model.fit(x, y, epochs=500)

# %%
equation(10)
# Out:
# 19

# %%
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 28ms/step
# [[18.983622]]

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)

print(model.predict([10.0]))

# %%
5* 10 - 1
# Out:
# 49

# %%
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 50ms/step
# [[48.96792]]

# %%
model = Sequential([Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1, 0, 1, 2, 3, 4])
ys = 5 * xs -1

model.fit(xs, ys, epochs=500)

#print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 197ms/step - loss: 154.1886
# Epoch 2/500
# 1/1 [==============================] - 0s 7ms/step - loss: 122.0412
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 96.7342
# Epoch 4/500
# 1/1 [==============================] - 0s 5ms/step - loss: 76.8090
# Epoch 5/500
# 1/1 [==============================] - 0s 6ms/step - loss: 61.1185
# Epoch 6/500
# 1/1 [==============================] - 0s 7ms/step - loss: 48.7597
# Epoch 7/500
# 1/1 [==============================] - 0s 5ms/step - loss: 39.0226
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 31.3484
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 25.2973
# Epoch 10/500
# 1/1 [==============================] - 0s 5ms/step - loss: 20.5237
# Epoch 11/500
# 1/1 [==============================] - 0s 5ms/step - loss: 16.7552
# Epoch 12/500
# ...
